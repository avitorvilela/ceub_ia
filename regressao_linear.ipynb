# %% [markdown]
# <a href="https://colab.research.google.com/github/avitorvilela/ceub_ia/blob/main/regressao_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Passo 1:**

# %%
import pandas as pd
df = pd.read_csv("/content/kc_house_data.csv")
print("Qtd. de linhas do data frame:", len(df))
print("Qtd. de colunas do data frame:", len(df.columns))
# ou df.shape
# Out:
# Qtd. de linhas do data frame: 21613
# Qtd. de colunas do data frame: 21

# %% [markdown]
# **Passo 2:** uma vez que os dados foram importados, vamos analisar os primeiros registros.

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ***Passo 3***: vimos que regressão linear trabalha bem com dados numéricos. Logo, vamos pedir para o ***Python*** mostrar os tipos dos dados das colunas.

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object
